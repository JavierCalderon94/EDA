# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
top1000 = pd.read_csv("data/1000_streamers_3.csv")
top1000
# Out:
#           streamer            href  media visualizaciones  horas stream  \
# 0           Jynxzi         /jynxzi                  97831         111.0
# 1             ibai           /ibai                  78200         117.6
# 2         KaiCenat       /kaicenat                  60974         110.5
# 3        auronplay      /auronplay                  67954          83.6
# 4          caseoh_        /caseoh_                  62387          97.3
# ..             ...             ...                    ...           ...
# 995         elyihi         /elyihi                   2608          97.5
# 996          梓澪與村長        /s201111                   3045          67.5
# 997  twitchmedia28  /twitchmedia28                   4360          13.3
# 998         Trebor         /trebor                   3801          31.5
# 999     nacho_dayo     /nacho_dayo                   3042          67.0
#
#      maximo historico  aumento followers  total followers  \
# ...

# %% [markdown]
# # Vamos a revisar los máximos.

# %% [markdown]
# TOP 5 por media de visualizaciones

# %%
ordenmedia = list(top1000.sort_values(by="media visualizaciones", ascending=False)["streamer"].values)
ordenmedia
sns.barplot(data = top1000, x="streamer", y="media visualizaciones", order=ordenmedia[0:5], color="#6340a3")
plt.title("TOP 5 por media de espectadores")
plt.ylabel("Media de espectadores")
plt.xlabel("")
plt.xticks(rotation=0);

# %%
ordenmax = list(top1000.sort_values(by="maximo historico", ascending=False)["streamer"].values)
ordenmedia
sns.barplot(data = top1000, x="streamer", y="maximo historico", order=ordenmax[0:5], color="#6340a3")
plt.title("TOP 5 por máximo histórico de espectadores")
plt.ylabel("Pico de espectadores")
plt.xlabel("")
plt.xticks(rotation=0);

# %%
ordensubs = list(top1000.sort_values(by="subs actuales", ascending=False)["streamer"].values)
ordenmedia
sns.barplot(data = top1000, x="streamer", y="subs actuales", order=ordensubs[0:5], color="#6340a3")
plt.title("TOP 5 por suscripciones")
plt.ylabel("Nº de suscripciones")
plt.xlabel("")
plt.xticks(rotation=0);

# %% [markdown]
# Idioma más frecuente dentro del TOP1000

# %%
ordenpaises = list(top1000["idioma"].value_counts().index)
sns.countplot(x=top1000["idioma"], order=ordenpaises, color="#6340a3")
plt.title("Idiomas dentro del TOP1000")
plt.xlabel("Idioma")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=60);

# %%
plt.figure(figsize=(8,8))
cuenta = top1000['idioma'].value_counts()
top_8 = cuenta[:7]
otros = pd.Series(cuenta[7:].sum(), index=['Otros'])
new_counts = pd.concat([top_8, otros])
plt.pie(new_counts, labels=new_counts.index, autopct=lambda p: '{:.1f}%'.format(p) if p > 1 else '', startangle=140, pctdistance=0.85, labeldistance=1.05)
plt.title("Idiomas en el Top 1000", loc="left", fontweight='bold')
plt.axis('equal')
plt.show()

# %%
ordenpaises = list(top1000["idioma"].value_counts().index)
sns.countplot(x=top1000["idioma"], order=ordenpaises, color="#6340a3")
plt.title("Idiomas dentro del TOP1000")
plt.xlabel("Idioma")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=60);

# %% [markdown]
# ¿Y el contenido más frecuente?

# %%
ordencontenido = list(top1000["contenido principal"].value_counts().index)
sns.countplot(x=top1000["contenido principal"], order=ordencontenido)
plt.title("Principal contenido dentro del TOP1000")
plt.xlabel("Contenido")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=90);

# %% [markdown]
# Hay demasiados tipos de contenido, más adelante analizaremos los primeros.

# %% [markdown]
# Es demasiado variado. Vamos a quedarnos con el TOP5

# %%
ordencontenido = list(top1000["contenido principal"].value_counts().index[0:5])
sns.countplot(x=top1000["contenido principal"], order=ordencontenido)
plt.title("Principal contenido dentro del TOP1000")
plt.xlabel("Contenido")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=90);

'''
ordencontenido = list(top1000["contenido principal"].value_counts().index[0:5])
sns.countplot(data=top1000, x="contenido principal", order=ordencontenido, hue="idioma", dodge=True)
plt.title("Principal contenido dentro del TOP1000")
plt.xlabel("Contenido")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=90);
'''
# Out:
# '\nordencontenido = list(top1000["contenido principal"].value_counts().index[0:5])\nsns.countplot(data=top1000, x="contenido principal", order=ordencontenido, hue="idioma", dodge=True)\nplt.title("Principal contenido dentro del TOP1000")\nplt.xlabel("Contenido")\nplt.ylabel("Nº de Streamers")\nplt.xticks(rotation=90);\n'

# %%
import pandas as pd
import plotly.express as px

# Crear el gráfico interactivo con Plotly
fig = px.histogram(top1000, x='contenido principal', color='idioma', title='Contenido Principal por Idioma',
                   labels={'contenido Principal': 'contenido Principal', 'count': 'Recuento'}, height=800, width=1000)

fig.update_xaxes(categoryorder='total descending')

# Mostrar el gráfico
fig.show()

# %% [markdown]
# De lejos el contenido más consumido es Just Chatting.

# %% [markdown]
# ¿Quienes son el TOP10 por media de espectadores?

# %%
top5 = top1000.sort_values(by="media visualizaciones", ascending=False)["streamer"][0:5]

# %% [markdown]
# # Correlación

# %%
correlacion = top1000.corr(numeric_only=True)

# %%
sns.heatmap(correlacion,
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación", fontweight='bold',)
# Out:
# Text(0.5, 1.0, 'Correlación')

# %%
correlacion_es = top1000[top1000["idioma"]=="Spanish"].corr(numeric_only=True)
sns.heatmap(correlacion_es,
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación Español", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación Español')

# %%
correlacion_en = top1000[top1000["idioma"]=="English"].corr(numeric_only=True)
sns.heatmap(correlacion_en,
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación Inglés", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación Inglés')

# %%
correlacion_de = top1000[top1000["idioma"]=="German"].corr(numeric_only=True)
sns.heatmap(correlacion_de,
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);

# %% [markdown]
# # Vamos a comprobar si la hipótesis de la influencia del idioma en el éxito en la plataforma

# %% [markdown]
# violin plot mostrando la distribución de media de seguidores por idioma

# %%
top1000_media = top1000.sort_values(by="media visualizaciones", ascending=False)

# %%
plt.figure(figsize=(15,5))
sns.violinplot(data=top1000[top1000["media visualizaciones"]<30000], x="idioma", y= "media visualizaciones", hue="idioma")
plt.xticks(rotation=45);

# %% [markdown]
# lo mismo pero ordenadcon boxplot

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=top1000_media, x="idioma", y= "media visualizaciones", hue="idioma")
plt.ylim(0, 20000)

plt.xticks(rotation=45)

plt.title("Comparación media por idioma", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Comparación media por idioma')

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=top1000_media, x="idioma", y= "media visualizaciones", hue="idioma")
sns.swarmplot(data=top1000_media, x="idioma", y="media visualizaciones", alpha=0.5, color="k")
plt.ylim(0, 20000)

plt.xticks(rotation=45)

plt.title("Comparación media por idioma", fontweight='bold')
# Out:
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 33.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 57.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# ...

# %%
plt.figure(figsize=(15,5))
sns.boxplot(data=top1000_media, x="idioma", y= "media visualizaciones", hue="idioma")
sns.swarmplot(data=top1000_media, x="idioma", y="media visualizaciones", alpha=0.9, color="k")
plt.ylim(0, 20000)

plt.xticks(rotation=45)

handles, labels = plt.gca().get_legend_handles_labels()
plt.legend(handles, labels, title='idioma')
# Out:
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 78.6% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 33.9% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 57.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# ...

# %% [markdown]
# Cogemos los 5 primeros paises

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=top1000_media[0:50], x="idioma", y= "media visualizaciones", hue="idioma")
sns.swarmplot(data=top1000_media[0:50], x="idioma", y="media visualizaciones", alpha=0.9, color="k")
# Out:
# <Axes: xlabel='idioma', ylabel='media visualizaciones'>

# %% [markdown]
# ordenado por la media, de mayor a menor

# %%
orden_idioma_media = list(top1000.groupby("idioma").aggregate({"media visualizaciones":"median"}).sort_values(by="media visualizaciones",ascending=False).index)

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=top1000_media, x="idioma", y= "media visualizaciones", order = orden_idioma_media)
plt.xticks(rotation=45);

# %% [markdown]
# Hay mucha dispersión, ¿Si filtramos por el TOP50?

# %%
plt.figure(figsize=(15,10))
sns.boxplot(top1000_media.iloc[0:50,:], x="idioma", y= "media visualizaciones", hue="idioma")
plt.xticks(rotation=45);

# %%
orden_idioma_media = list(top1000.iloc[0:100].groupby("idioma").aggregate({"media visualizaciones":"median"}).sort_values(by="media visualizaciones",ascending=False).index.unique())

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=top1000_media[0:100], x="idioma", y="media visualizaciones", hue="idioma", inner=None)
sns.swarmplot(data=top1000_media[0:100], x="idioma", y="media visualizaciones", alpha=0.9, color="k")
plt.title("TOP 100 - Comparación media por idioma", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'TOP 100 - Comparación media por idioma')

# %% [markdown]
# ¿Y el resto?

# %%
orden_idioma_media = list(top1000.iloc[100:,:].groupby("idioma").aggregate({"media visualizaciones":"mean"}).sort_values(by="media visualizaciones",ascending=False).index)
plt.figure(figsize=(15,10))
sns.boxplot(top1000.iloc[100:,:], x="idioma", y= "media visualizaciones", order = orden_idioma_media, hue="idioma")
plt.xticks(rotation=45);

# %%
orden_idioma_media = list(top1000.iloc[100:,:].groupby("idioma").aggregate({"media visualizaciones":"mean"}).sort_values(by="media visualizaciones",ascending=False).index)
plt.figure(figsize=(15,10))
sns.violinplot(top1000.iloc[100:,:], x="idioma", y= "media visualizaciones", order = orden_idioma_media, hue="idioma")
plt.xticks(rotation=45);

# %%
plt.figure(figsize=(15,10))
sns.boxplot(data=top1000, x="idioma", y= "media visualizaciones", order = orden_idioma_media)
plt.xticks(rotation=45);

# %%
top1000_maximo = top1000.sort_values(by="maximo historico", ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=top1000_maximo[0:100], x="idioma", y="maximo historico", hue="idioma", inner=None)
sns.swarmplot(data=top1000_maximo[0:100], x="idioma", y="maximo historico", alpha=0.9, color="k")
plt.yticks(range(100000, 4000000, 500000))
plt.title("TOP 100 - Comparación máximos por idioma", fontweight='bold');
# Out:
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 10.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
top1000_followers = top1000.sort_values(by="total followers", ascending=False)

# %%
plt.figure(figsize=(15,10))
sns.violinplot(data=top1000_followers[0:100], x="idioma", y="total followers", hue="idioma", inner=None)
sns.swarmplot(data=top1000_followers[0:100], x="idioma", y="total followers", alpha=0.9, color="k")
plt.title("TOP 100 - Comparación seguidores por idioma", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'TOP 100 - Comparación seguidores por idioma')

# %%
top1000_subs = top1000.sort_values(by="subs actuales", ascending=False)
plt.figure(figsize=(15,10))
sns.violinplot(data=top1000_subs[0:100], x="idioma", y="subs actuales", hue="idioma", inner=None)
sns.swarmplot(data=top1000_subs[0:100], x="idioma", y="subs actuales", alpha=0.9, color="k")
plt.title("TOP 100 - Comparación suscripciones por idioma", fontweight='bold')
# Out:
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 15.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# Text(0.5, 1.0, 'TOP 100 - Comparación suscripciones por idioma')
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 13.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.

# %%
plt.figure(figsize=(15, 5))

plt.subplot(1, 3, 1)
sns.barplot(data=top1000_media, x='idioma', y='media visualizaciones')
plt.title('Media de Visualizaciones por Idioma')
plt.xticks(rotation=90)

plt.subplot(1, 3, 2)
sns.barplot(data=top1000_media, x='idioma', y='maximo historico')
plt.title('Máximo Histórico por Idioma')
plt.xticks(rotation=90)

plt.subplot(1, 3, 3)
sns.barplot(data=top1000_media, x='idioma', y='total followers')
plt.title('Total de Seguidores por Idioma')
plt.xticks(rotation=90)

plt.tight_layout()
plt.show()

# %% [markdown]
# # Vamos a analizar la parte relativa a la relación del contenido con el éxito en la platafoma

# %%
ordencontenido = list(top1000["contenido principal"].value_counts().index)
sns.countplot(x=top1000["contenido principal"], order=ordencontenido[0:10], color="#6340a3")
plt.title("Principal contenido dentro del TOP1000")
plt.xlabel("Contenido")
plt.ylabel("Nº de Streamers")
plt.xticks(rotation=90);

# %% [markdown]
# ¿Si hacemos la suma de las medias por creador y comparamos por país?

# %%
import pandas as pd
import plotly.express as px

# Crear el gráfico interactivo con Plotly
fig = px.histogram(top1000_media, x='contenido principal', y="media visualizaciones", color='idioma', title='Contenido Principal por Idioma',
                   labels={'contenido Principal': 'contenido Principal', 'count': 'Recuento'}, height=800, width=1000)

fig.update_xaxes(categoryorder='total descending')

# Mostrar el gráfico
fig.show()

# %% [markdown]
# Dentro de los 1000 principales streamers inicialmente podemos observar como el contenido más frecuente es Just Chatting, pero no necesariamente tiene que ser el más relevante. ¿Si lo analizamos en función a la media de espectadores de cada tipo de contenido por país?

# %%
top1000_media2 = top1000_media.groupby(["contenido principal","idioma"]).aggregate({"media visualizaciones":"mean"}).reset_index().sort_values(by="media visualizaciones",ascending=False)

# %%
import pandas as pd
import plotly.express as px

# Crear el gráfico interactivo con Plotly
fig = px.histogram(top1000_media2, x='contenido principal', y="media visualizaciones", color='idioma', title='Contenido Principal por Idioma',
                   labels={'contenido Principal': 'contenido Principal', 'count': 'Recuento'}, height=800, width=1000)

fig.update_xaxes(categoryorder='total descending')

# Mostrar el gráfico
fig.show()

# %% [markdown]
# Sigue siendo el más común, pero sigue habiendo algo mal. ¿Los creadores de contenido únicamente retransmiten un juego? Vamos a importar el segundo dataset en el que tenemos los datos de los últimos 40 streams de cada creador para revisar si es verdad que el contenido más retransmitido es Just Chatting.

# %%
last_40 = pd.read_csv("data/DATOS_STREAMS_FINAL2.csv")

# %%
last_40
# Out:
#          streamer             fecha  duracion(horas)  media viewers  \
# 0          Jynxzi  08/03/2024 21:53              1.3          59134
# 1          Jynxzi  08/03/2024 00:57              4.5         127516
# 2          Jynxzi  06/03/2024 00:59              3.4          88533
# 3          Jynxzi  05/03/2024 00:59              5.1          94622
# 4          Jynxzi  04/03/2024 01:40              1.2         106993
# ...           ...               ...              ...            ...
# 39133  nacho_dayo  21/12/2023 04:05             13.8           3239
# 39134  nacho_dayo  20/12/2023 13:44              4.2           1663
# 39135  nacho_dayo  19/12/2023 11:11              6.2           1419
# 39136  nacho_dayo  18/12/2023 08:08             13.8           2786
# 39137  nacho_dayo  17/12/2023 04:03             11.3           3316
#
#        max viewers  followers                     contenido 1    contenido 2  \
# ...

# %%
recuento_last_40 = pd.DataFrame({"recuento":pd.concat([last_40["contenido 1"],last_40["contenido 2"],last_40["contenido 3"],last_40["contenido 4"]]).dropna().value_counts()}).reset_index()

# %%
recuento_last_40
# Out:
#                       index  recuento
# 0             Just Chatting     14453
# 1         League of Legends      4138
# 2        Grand Theft Auto V      3669
# 3                  VALORANT      2707
# 4                  Fortnite      1984
# ...                     ...       ...
# 1880         Fractured Veil         1
# 1881  Stargate: Timekeepers         1
# 1882       At Dead of Night         1
# 1883        Resident Evil 5         1
# 1884          The Matriarch         1
#
# [1885 rows x 2 columns]

# %%
sns.barplot(data=recuento_last_40[0:10], x="index",y="recuento")
plt.title("Recuento del contenido de los últimos streams")
plt.xlabel("Contenido")
plt.ylabel("Recuento")
plt.xticks(rotation=90);

# %% [markdown]
# Está claro que el contenido más consumido es Just Chatting y apenas se producen cambios. Ahora, ya que cada creador de contenido está relacionado con un tipo de juego en específico, vamos a analizar si el que haga su contenido, lo mezcle con otros juegos, haga un stream de otra cosa o junte varios otros juegos influye en que le vaya mejor/peor en ese stream.

# %%
last_40
# Out:
#          streamer             fecha  duracion(horas)  media viewers  \
# 0          Jynxzi  08/03/2024 21:53              1.3          59134
# 1          Jynxzi  08/03/2024 00:57              4.5         127516
# 2          Jynxzi  06/03/2024 00:59              3.4          88533
# 3          Jynxzi  05/03/2024 00:59              5.1          94622
# 4          Jynxzi  04/03/2024 01:40              1.2         106993
# ...           ...               ...              ...            ...
# 39133  nacho_dayo  21/12/2023 04:05             13.8           3239
# 39134  nacho_dayo  20/12/2023 13:44              4.2           1663
# 39135  nacho_dayo  19/12/2023 11:11              6.2           1419
# 39136  nacho_dayo  18/12/2023 08:08             13.8           2786
# 39137  nacho_dayo  17/12/2023 04:03             11.3           3316
#
#        max viewers  followers                     contenido 1    contenido 2  \
# ...

# %%
last_40_contenido = last_40.groupby(["streamer","resumen"]).aggregate({"media viewers":"mean","max viewers":"mean","followers":"mean"}).reset_index()

# %%
last_40_contenido["media viewers"].sort_values(ascending=False)
# Out:
# 623     131151.000000
# 1779    124786.750000
# 1727    124786.750000
# 622     114687.571429
# 1271     98868.333333
#             ...
# 1399        41.400000
# 1398        28.846154
# 1397        21.000000
# 2015         6.000000
# 2016         5.250000
# Name: media viewers, Length: 2449, dtype: float64

# %%
last_40_contenido.corr(numeric_only=True)
# Out:
#                media viewers  max viewers  followers
# media viewers       1.000000     0.979828   0.624123
# max viewers         0.979828     1.000000   0.609608
# followers           0.624123     0.609608   1.000000

# %%
sns.heatmap(last_40_contenido.corr(numeric_only=True),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación en directos", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación en directos')

# %%
orden = ['Propio','Propio + otros','Otro contenido','Otro contenido o más']

# %%
sns.heatmap(last_40.loc[last_40['resumen']=='Otro contenido',["media viewers","max viewers","followers"]].corr(numeric_only=True),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación en directos para 1 juego diferente", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación en directos para 1 juego diferente')

# %%
sns.heatmap(last_40.loc[last_40['resumen']=='Propio + otros',["media viewers","max viewers","followers"]].corr(numeric_only=True),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación en directos para contenido habitual y otros", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación en directos para contenido habitual y otros')

# %%
sns.heatmap(last_40.loc[last_40['resumen']=='Propio',["media viewers","max viewers","followers"]].corr(numeric_only=True),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación en directos para contenido habitual", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación en directos para contenido habitual')

# %%
sns.heatmap(last_40.loc[last_40['resumen']=='Otro contenido o más',["media viewers","max viewers","followers"]].corr(numeric_only=True),
            vmin=-1,
            vmax=1,
            cmap=sns.diverging_palette(145, 280, s=85, l=25, n=7),
            square=True,
            linewidths=.1,
            annot=True);
plt.title("Correlación en directos para +1 contenido diferente", fontweight='bold')
# Out:
# Text(0.5, 1.0, 'Correlación en directos para +1 contenido diferente')

# %%
last_40["resumen"].value_counts()
# Out:
# resumen
# Propio                  17668
# Propio + otros           9323
# Otro contenido           7925
# Otro contenido o más     4222
# Name: count, dtype: int64

# %% [markdown]
# No hay una diferencia significativa en cuanto a correlación, sí están un poco más correladas cuando el streamer hace contenido que no es el suyo o mecla que cuando hace el propio pero no es una diferencia drástica.
#
# Veamos si en cambio los datos varían.

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(data=last_40[(last_40["media viewers"]>0)&(last_40["media viewers"]<17500)], x="resumen", y="media viewers", palette=paleta_colores, order=orden).set_ylim(0,14000)
plt.title("Comparación media espectadores por contenido del directo", fontweight='bold')
plt.xlabel("");
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_16720\4051993454.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(10, 5))
sns.violinplot(data=last_40[(last_40["followers"]>0)&(last_40["followers"]<2000)], x="resumen", y="followers", palette=paleta_colores, order=orden).set_ylim(0,1700)
plt.title("Comparación aumento de seguidores por contenido del directo", fontweight='bold')
plt.xlabel("");
# Out:
# C:\Users\javie\AppData\Local\Temp\ipykernel_16720\707922068.py:2: FutureWarning:
#
#
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.

# %%
plt.figure(figsize=(15,15))
sns.lmplot(data=last_40, x="media viewers", y="followers", hue="resumen", scatter=False)

# %%
plt.figure(figsize=(15,15))
sns.swarmplot(data=last_40_contenido, x="media viewers", y="followers", hue="resumen")
# Out:
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 50.0% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 33.3% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#
# c:\Users\javie\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\categorical.py:3399: UserWarning:
#
# 66.7% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
# <Axes: xlabel='media viewers', ylabel='followers'>
